# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd
df = pd.read_csv('emendas.csv')
df.head(10)
# Out:
# /tmp/ipykernel_2038/543231991.py:2: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('emendas.csv')
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Eu observo as dez primeiras linhas do dataframe contendo informações sobre uma emenda, suas finalidades, valores, onde foi implementada e etc.

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (86589, 28)

# %% [markdown]
# Esses números significam, respectivamente, a quantidade de linhas e colunas que o DataFrame possui.

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns
# Out:
# Index(['Código da Emenda', 'Ano da Emenda', 'Tipo de Emenda',
#        'Código do Autor da Emenda', 'Nome do Autor da Emenda',
#        'Número da emenda', 'Localidade de aplicação do recurso',
#        'Código Município IBGE', 'Município', 'Código UF IBGE', 'UF', 'Região',
#        'Código Função', 'Nome Função', 'Código Subfunção', 'Nome Subfunção',
#        'Código Programa', 'Nome Programa', 'Código Ação', 'Nome Ação',
#        'Código Plano Orçamentário', 'Nome Plano Orçamentário',
#        'Valor Empenhado', 'Valor Liquidado', 'Valor Pago',
#        'Valor Restos A Pagar Inscritos', 'Valor Restos A Pagar Cancelados',
#        'Valor Restos A Pagar Pagos'],
#       dtype='object')

# %% [markdown]
# Código da Emenda: Identificador único da emenda.
# Ano da Emenda: Ano de registro da emenda.
# Tipo de Emenda: Categoria da emenda (individual, bancada, etc.).
# Código do Autor da Emenda: Identificador do autor.
# Nome do Autor da Emenda: Nome do parlamentar autor.
# Número da Emenda: Número oficial da emenda.
# Localidade de aplicação do recurso: Onde o recurso será aplicado.
# Código Município IBGE: Código oficial do município (IBGE).
# Município: Nome da cidade.
# Código UF IBGE: Código oficial do estado (IBGE).
# UF: Sigla do estado.
# Região: Região do país.
# Código Função: Código da área principal do gasto.
# Nome Função: Nome da área (ex: saúde, educação).
# Código Subfunção: Código da subárea.
# Nome Subfunção: Nome da subárea.
# Código Programa: Código do programa de governo.
# Nome Programa: Nome do programa.
# Código Ação: Código da ação.
# Nome Ação: Nome da ação.
# Código Plano Orçamentário: Código detalhado da aplicação.
# Nome Plano Orçamentário: Nome do plano orçamentário.
# Valor Empenhado: Valor reservado para o gasto.
# Valor Liquidado: Valor já confirmado após execução.
# Valor Pago: Valor efetivamente pago.
# Valor Restos a Pagar Inscritos: Valores não pagos no ano e transferidos.
# Valor Restos a Pagar Cancelados: Valores que foram cancelados.
# Valor Restos a Pagar Pagos: Valores pagos posteriormente.

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
nulos = df.isnull().sum()
print(nulos)
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             1
# Nome Plano Orçamentário               1
# Valor Empenhado                       1
# ...

# %% [markdown]
# Sim, existem 8 valores nulos.

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
df.dtypes
# Out:
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# Nome Função                           object
# Código Subfunção                      object
# Nome Subfunção                        object
# Código Programa                       object
# Nome Programa                         object
# Código Ação                           object
# Nome Ação                             object
# Código Plano Orçamentário             object
# ...

# %% [markdown]
# Todos os códigos ficariam mais otimizados caso fossem inteiros, e todos os valores ficariam melhores como float.

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
df.sort_values(by='Ano da Emenda', ascending=False).head(8)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 86567     202544200001           2025
# 86581     202537240006           2025
# 86558     202592040006           2025
# 86559     202592040007           2025
# 86560     202592040008           2025
# 86561     202592040009           2025
# 86562     202541610001           2025
# 86563     202541610002           2025
#
#                                           Tipo de Emenda  \
# 86567  Emenda Individual - Transferências com Finalid...
# 86581  Emenda Individual - Transferências com Finalid...
# 86558  Emenda Individual - Transferências com Finalid...
# 86559       Emenda Individual - Transferências Especiais
# 86560  Emenda Individual - Transferências com Finalid...
# 86561  Emenda Individual - Transferências com Finalid...
# 86562  Emenda Individual - Transferências com Finalid...
# 86563  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# O ano mais recente presente no dataset é 2025, pois estamos pedindo para o código pegar do maior ano até o menor.

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   86589.000000    8.658900e+04
# mean     2019.019633    2.946591e+06
# std         3.329069    1.262527e+06
# min      2014.000000   -1.400000e+01
# 25%      2016.000000    2.300000e+06
# 50%      2019.000000    3.100000e+06
# 75%      2022.000000    3.500000e+06
# max      2025.000000    5.300000e+06

# %% [markdown]
# Apenas aparecem as colunas que foram identificadas como int64, sendo analisadas como números e podendo serem processadas em operações matemáticas, já as outras não foram, mesmo as que também possuem números como informação.

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail(5)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 86584     202544210003           2025
# 86585     202544220001           2025
# 86586     202544220002           2025
# 86587     202544220003           2025
# 86588     202544220004           2025
#
#                                           Tipo de Emenda  \
# 86584  Emenda Individual - Transferências com Finalid...
# 86585  Emenda Individual - Transferências com Finalid...
# 86586       Emenda Individual - Transferências Especiais
# 86587       Emenda Individual - Transferências Especiais
# 86588  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 86584                      4421          MARCOS TAVARES                3
# 86585                      4422            MARIA ARRAES                1
# 86586                      4422            MARIA ARRAES                2
# 86587                      4422            MARIA ARRAES                3
# ...

# %% [markdown]
# Tem 8 informações nulas, tornando a linha difícil de analisar.

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Não existem valores duplicados no dataframe.
